# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import pylab 

#df =pd.ExcelFile('/content/drive/My Drive/Case/nanoBloodProject/rg/homo/152lig/lig/RgLigWhole.xlsx')# the name of execl file should start with capital word. Rdf is correct but not rdf 
df =pd.ExcelFile(r'C:\vmd\densProf_last_frame.xlsx')
Sheet1 =pd.read_excel(df,header=0)

ax=Sheet1.plot(kind='line',x= 'a', y= 'EG', color='tab:cyan', linewidth=0.9, label='EG')
ax.legend()
Sheet1.plot(kind='line', x= 'a', y= 'recept', color='purple', linewidth=0.9, label='receptor', ax=ax)
#Sheet1.plot(kind='line', y= 'wall', color='green', linewidth=0.7, label='wall', ax=ax)
#Sheet1.plot(kind='line', y= 'water', color='brown', linewidth=0.7, label='water', ax=ax)
#Sheet1.plot(kind='line',x= 'a', y= 'C', color='orange', linewidth=0.9, label='C', ax=ax)
Sheet1.plot(kind='line',x= 'a', y= 'N', color='brown', linewidth=0.9, label='N', ax=ax)
Sheet1.plot(kind='line',x= 'a', y= 'lig', color='black', linewidth=0.9, label='ligand', ax=ax)
ax.legend()

ax.set_xlabel('Z')
ax.set_ylabel('density') 
pylab.xlim([0,30])
pylab.ylim([0,0.02])# define the range of y coordinate
plt.ticklabel_format(axis="both", style="sci", scilimits=(0,0))#show the x and y axis in scientific mode
#plt.savefig('/content/drive/My Drive/Case/nanoBloodProject/rg/homo/152lig/lig/RgLigWhole.png')
plt.savefig(r'C:\vmd\densProf_last_frame(3).png')

# %% [markdown]
# # thankGOD! final correct units

# %%
#ThankGOD correct plot units

import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import pylab 
from matplotlib import rcParams
import matplotlib


#df =pd.ExcelFile('/content/drive/My Drive/Case/nanoBloodProject/rg/homo/152lig/lig/RgLigWhole.xlsx')# the name of execl file should start with capital word. Rdf is correct but not rdf 
df =pd.ExcelFile(r'C:\vmd\density_profile_last_frame.xlsx')
last =pd.read_excel(df,header=0)

ax=last.plot(kind='line',x= 'a', y= 'EG', color='tab:cyan', linewidth=1.5, label='EG')
ax.legend()
last.plot(kind='line', x= 'a', y= 'recept', color='purple', linewidth=1.5, label='receptor', ax=ax)
#Sheet1.plot(kind='line', y= 'wall', color='green', linewidth=0.7, label='wall', ax=ax)
#Sheet1.plot(kind='line', y= 'water', color='brown', linewidth=0.7, label='water', ax=ax)
#Sheet1.plot(kind='line',x= 'a', y= 'C', color='orange', linewidth=0.9, label='C', ax=ax)
last.plot(kind='line',x= 'a', y= 'N', color='orange', linewidth=1.5, label='N', ax=ax)
last.plot(kind='line',x= 'a', y= 'lig', color='black', linewidth=1.5, label='ligand', ax=ax)
ax.legend()

##########################################
ax.set_xlabel('Z (1.0nm)')
ax.set_ylabel('density (nm^-2)') 
#ax.set_yscale('log') #to plot in log scale

pylab.xlim([1,30])
plt.xticks(np.arange(0,31,10)) #the distance of units to be shown in x axis. it starts from 10 to 30 with idistance of 10.thankGOD!
pylab.ylim([0.0,0.02])# define the range of y coordinate
plt.yticks(np.arange(0,0.021,0.01))

rcParams['font.family'] = 'serif'
rcParams['font.sans-serif'] = ['Bitstream Vera Sans']
rcParams['font.serif'] = ['Bitstream Vera Sans']
rcParams["font.size"] = "17"
matplotlib.rcParams['legend.fontsize'] = 10

plt.rcParams["figure.figsize"] = [5.50, 4.0]
plt.rcParams["figure.autolayout"] = True

plt.ticklabel_format(axis="both", style="plain", scilimits=(0,0))#show the x and y axis in scientific 
###########################################
#ax.set_ylabel('distance (0.1nm)') 
#ax.set_xlabel('Z')
#ax.set_ylabel('density') 
#pylab.xlim([0,30])
#pylab.ylim([0,0.02])# define the range of y coordinate
#plt.ticklabel_format(axis="both", style="sci", scilimits=(0,0))#show the x and y axis in scientific mode
#plt.savefig('/content/drive/My Drive/Case/nanoBloodProject/rg/homo/152lig/lig/RgLigWhole.png')
plt.savefig(r'C:\vmd\density_profile_last_frame(3).png')
